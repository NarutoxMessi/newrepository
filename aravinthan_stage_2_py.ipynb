# %% [markdown]
# <a href="https://colab.research.google.com/github/NarutoxMessi/newrepository/blob/google-colab/aravinthan_stage_2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Add Result Check
num1 = float(input("enter a number"))
num2 = float(input("enter a number"))
op = input("select a operator +,-,*,/:")
if op == "+":
  result = num1+num2
  print(result)
elif op == "-":
  result = num1-num2
  print(result)
elif op == "*":
  result = num1*num2
  print(result)
elif op == "/":
  if num2!=0:
    result = num1/num2
    print(result)
  else:
    print("divisible by 0 is infinity")
else:
  print("select correct operator in the list")
if result > 0:
             print("result is Positive")
elif result < 0:
             print("result is Negative")
else:
             print("result is 0")
# Out:
# enter a number15
# enter a number15
# select a operator +,-,*,/:-
# 0.0
# result is 0
